# %%
import numpy as np
import pandas as pd
import sys
sys.path.append('../')

# %%
listaEquipos = pd.read_csv('/Users/mariaperez-serrabona/UEFA_champions/docs/equipo.csv')
listaEquipos
# Out:
#               Equipo                  Foto          País   Puesto
# 0               Ajax              ajax.png  Paises Bajos       14
# 1           Atalanta          atalanta.png        Italia        6
# 2           Atlético          atletico.png        España       11
# 3          Barcelona         barcelona.png        España       17
# 4             Bayern            bayern.png      Alemania       16
# 5            Benfica           benfica.png      Portugal       15
# 6           Besiktas          besiktas.png       Turquía        2
# 7            Chelsea           chelsea.png    Inglaterra        1
# 8        Club Brugge       club_brugge.png       Bélgica       26
# 9           Dortmund          dortmund.png      Alemania       27
# 10       Dynamo Kyiv       dynamo_kyiv.png       Ucrania       28
# 11    Internazionale    internazionale.png        Italia       29
# 12          Juventus          juventus.png        Italia        9
# 13           Leipzig           leipzig.png      Alemania        8
# 14         Liverpool         liverpool.png    Inglaterra       24
# 15              LOSC              losc.png       Francia       23
# 16             Malmö             malmo.png        Suecia       22
# 17         Man. City          man_city.png    Inglaterra       21
# 18       Man. United        man_united.png    Inglaterra       20
# 19             Milan             milan.png        Italia       19
# 20             Paris             paris.png       Francia       14
# 21             Porto             porto.png      Portugal       13
# 22       Real Madrid       real_madrid.png        España       12
# 23          Salzburg          salzburg.png       Austria       11
# 24           Sevilla           sevilla.png        España       10
# 25  Shakhtar Donetsk  shakhtar_donetsk.png       Ucrania       14
# 26           Sheriff           sheriff.png      Moldavia       22
# 27       Sporting CP       sporting_cp.png      Portugal       25
# 28        Villarreal        villarreal.png        España       30
# 29         Wolfsburg         wolfsburg.png      Alemania        4
# 30        Young Boys        young_boys.png         Suiza        7
# 31             Zenit             zenit.png         Rusia       13

# %%
#vamos a ver que todos en todos los casos, los equipos se nombren igual
listaEquipos['Equipo'].unique()
# Out:
# array(['Ajax', 'Atalanta', 'Atlético', 'Barcelona', 'Bayern', 'Benfica',
#        'Besiktas', 'Chelsea', 'Club Brugge', 'Dortmund', 'Dynamo Kyiv',
#        'Internazionale', 'Juventus', 'Leipzig', 'Liverpool', 'LOSC',
#        'Malmö', 'Man. City', 'Man. United', 'Milan', 'Paris', 'Porto',
#        'Real Madrid', 'Salzburg', 'Sevilla', 'Shakhtar Donetsk',
#        'Sheriff', 'Sporting CP', 'Villarreal', 'Wolfsburg', 'Young Boys',
#        'Zenit'], dtype=object)

# %%
#tenemos que cargar todos los partidos de los últimos 10 años en un bucle
# creamos entonces una lista con todos los años

años = ["2020-21","2019-20","2018-19","2017-18","2015-16","2014-15","2013-14","2012-13","2011-12","2010-11","2009-10","2008-09"
    ,"2007-08","2006-07","2005-06","2004-05","2003-04","2002-03","2001-02","2000-01"]

# %%
lista_ch_1=pd.read_csv('/Users/mariaperez-serrabona/UEFA_champions/datas/Champions/resultados_2000-01.csv')
lista_ch_1
# Out:
#                  Local  GolesLocal  GolesVisitante          Visitante
# 0       Spartak Moscú            2               0  Bayer Leverkusen
# 1          Sporting CP           2               2        Real Madrid
# 2    Bayer Leverkusen            3               2        Sporting CP
# 3          Real Madrid           1               0     Spartak Moscú
# 4       Spartak Moscú            3               1        Sporting CP
# ..                 ...         ...             ...                ...
# 139             Lazio            2               2        Real Madrid
# 140        Real Madrid           3               2      Leeds United
# 141             Lazio            2               1        Anderlecht
# 142      Leeds United            3               3             Lazio
# 143        Anderlecht            2               0        Real Madrid
#
# [144 rows x 4 columns]

# %%
lista_ch_1['Local'].unique()
# Out:
# array(['Spartak Moscú ', 'Sporting CP', 'Bayer Leverkusen ',
#        'Real Madrid', 'Sparta Praha ', 'Shakhtar Donetsk', 'Arsenal ',
#        'Lazio ', 'Valencia ', 'Olympique de Lyon ', 'Olympiakos ',
#        'Heerenveen ', 'Olympiacos ', 'Galatasaray ', 'Rangers ',
#        'Mónaco ', 'Sturm Graz ', 'Hamburgo ', 'Panathinaikos ',
#        'Juventus', 'Dep. de La Coruña ', 'Rosenborg ', 'Helsingborgs ',
#        'París Saint-Germain ', 'Bayern', 'PSV Eindhoven ', 'Man. United',
#        'Dinamo Kiev ', 'Anderlecht ', 'Barcelona', 'Milan',
#        'Leeds United ', 'Beşiktaş ', 'Deportivo de La Coruña '],
#       dtype=object)

# %%
lista_ch_1['Visitante'].unique()
# Out:
# array(['Bayer Leverkusen ', 'Real Madrid', 'Sporting CP',
#        'Spartak Moscú ', 'Arsenal ', 'Lazio ', 'Shakhtar Donetsk',
#        'Sparta Praha ', 'Olympiacos ', 'Heerenveen ', 'Olympique Lyon ',
#        'Valencia ', 'Olympique de Lyon ', 'Mónaco ', 'Sturm Graz ',
#        'Rangers ', 'Galatasaray ', 'Juventus', 'Dep. de La Coruña ',
#        'Panathinaikos ', 'Hamburgo ', 'París Saint-Germain ', 'Bayern',
#        'Helsingborgs ', 'Rosenborg ', 'Dinamo Kiev ', 'Anderlecht ',
#        'Man. United', 'PSV Eindhoven ', 'Leeds United ', 'Beşiktaş ',
#        'Milan', 'Barcelona', 'Deportivo de La Coruña '], dtype=object)

# %%
# como podemos observar, los nombres de algunos equipos varían dependiendo si son visitantes o locales
# para poder hacer un buen análisis de los datos es necesario que se llamen igual en ambos casos
#los recorreremos y cambiaremos los nombres en los casos en los que sea necesario

#Normalizamos los nombres de los equipos
for año in años:
    data=pd.read_csv(f'datas/Champions/resultados{año}.csv')
    diccionario={}
    for nombre in data.Local.unique():
        lista=str(nombre).lower().split()
        if 'inter' in lista:
            diccionario[nombre]='Internazionale'
        for equipo in equipos:
            if str(equipo).lower() in lista:
                diccionario[nombre]=str(equipo)
        if 'manchester' in lista:
            if 'united' in lista:
                diccionario[nombre]='Man. United'
            elif 'city' in lista:
                diccionario[nombre]='Man. City'
        elif 'lille' in lista:
            diccionario[nombre]='LOSC'
        elif 'París' in lista:
            diccionario[nombre]='Paris'
        elif 'sporting' in lista:
            if 'portugal' in lista:
                diccionario[nombre]='Sporting CP'
        elif 'donetsk' in lista:
            diccionario[nombre]='Shakhtar Donetsk'
        elif 'real' in lista:
            if 'madrid' in lista:
                diccionario[nombre]='Real Madrid'
        elif 'young' in lista:
            diccionario[nombre]='Young Boys'
    
    for nombre in diccionario:
        data["Local"] = data["Local"].replace(nombre,diccionario[nombre])
        data["Visitante"] = data["Visitante"].replace(nombre,diccionario[nombre])
    data.to_csv(f'Datos/resultados{año}.csv',index=False)

#Normalizamos los nombres de los equipos
def NormalizacionNombres(palabra:str):
    palabra=palabra.lower()
    palabra=palabra.replace("á","a")
    palabra=palabra.replace("é","e")
    palabra=palabra.replace("í","i")
    palabra=palabra.replace("ó","o")
    palabra=palabra.replace("ö","o")
    palabra=palabra.replace("ú","u")
    palabra=palabra.replace("ü","u")
    palabra=palabra.replace("ç","c")
    return palabra
